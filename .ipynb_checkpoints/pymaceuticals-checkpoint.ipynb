# %% [markdown]
# # Pymaceuticals
# - The sex distribution between the mice in the study is pretty even, with 51% males in the study and 49% females.
# - Based on the boxplot, Capomulin and Ramicane seem to be the most effective treatments against SCC, as they resulted in the lowest median tumor volume at the end of the regimen.
# - Based on the results for the Capomulin regimen, there is a positive correlation between the weight of the mice and the average volume of their tumor. The correlation coefficient between the two variables is 0.84, which indicates a strong correlation (rvalue > 0.7).

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
from scipy.stats import stats
import numpy as np

# Read the mouse data and the study results
mouseData = pd.read_csv("data/Mouse_metadata.csv")
studyResults = pd.read_csv("data/Study_results.csv")

# Combine the data into a single dataset
studyData = pd.merge(studyResults, mouseData, how="left", on="Mouse ID")

# Display the data table for preview
studyData.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
# 2     g107          0                45.0                 0     Ketapril
# 3     a457          0                45.0                 0     Ketapril
# 4     c819          0                45.0                 0     Ketapril
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29
# 2  Female           2          29
# 3  Female          11          30
# 4    Male          21          25

# %%
# Checking the number of mice.
len(studyData["Mouse ID"].unique())
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
duplicates = studyData.duplicated(subset=["Mouse ID", "Timepoint"], keep=False) 
studyData[duplicates] # returns duplicates based on Mouse ID and Timepoint
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 107      g989          0           45.000000                 0     Propriva
# 137      g989          0           45.000000                 0     Propriva
# 329      g989          5           48.786801                 0     Propriva
# 360      g989          5           47.570392                 0     Propriva
# 620      g989         10           51.745156                 0     Propriva
# 681      g989         10           49.880528                 0     Propriva
# 815      g989         15           51.325852                 1     Propriva
# 869      g989         15           53.442020                 0     Propriva
# 950      g989         20           55.326122                 1     Propriva
# 1111     g989         20           54.657650                 1     Propriva
#
#          Sex  Age_months  Weight (g)
# 107   Female          21          26
# 137   Female          21          26
# ...

# %%
# Optional: Get all the data for the duplicate mouse ID (g989). 
duplicateDF = studyData[studyData["Mouse ID"] == "g989"]
duplicateDF
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 107      g989          0           45.000000                 0     Propriva
# 137      g989          0           45.000000                 0     Propriva
# 329      g989          5           48.786801                 0     Propriva
# 360      g989          5           47.570392                 0     Propriva
# 620      g989         10           51.745156                 0     Propriva
# 681      g989         10           49.880528                 0     Propriva
# 815      g989         15           51.325852                 1     Propriva
# 869      g989         15           53.442020                 0     Propriva
# 950      g989         20           55.326122                 1     Propriva
# 1111     g989         20           54.657650                 1     Propriva
# 1195     g989         25           56.045564                 1     Propriva
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
cleanedDF = studyData[studyData["Mouse ID"] != "g989"]
cleanedDF.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
# 2     g107          0                45.0                 0     Ketapril
# 3     a457          0                45.0                 0     Ketapril
# 4     c819          0                45.0                 0     Ketapril
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29
# 2  Female           2          29
# 3  Female          11          30
# 4    Male          21          25

# %%
# Checking the number of mice in the clean DataFrame.
len(cleanedDF["Mouse ID"].unique())
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume.
DrugGroupedDF = cleanedDF.groupby(["Drug Regimen"])
mean = DrugGroupedDF["Tumor Volume (mm3)"].mean()
median = DrugGroupedDF["Tumor Volume (mm3)"].median()
variance = DrugGroupedDF["Tumor Volume (mm3)"].var()
std = DrugGroupedDF["Tumor Volume (mm3)"].std()
sem = DrugGroupedDF["Tumor Volume (mm3)"].sem()

# Assemble the resulting series into a single summary dataframe.

summaryTable = pd.DataFrame({
    "Mean Tumor Volume": mean,
    "Median Tumor Volume": median,
    "Tumor Volume Variance": variance, 
    "Tumor Volume Std. Dev.": std,
    "Tumor Volume Std. Err.": sem
})

summaryTable
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variance  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.320930            50.446266              43.852013
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Tumor Volume Std. Dev.  Tumor Volume Std. Err.
# Drug Regimen
# ...

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
# Using the aggregation method, produce the same summary statistics in a single line
summaryTable2 = cleanedDF.groupby("Drug Regimen")["Tumor Volume (mm3)"].aggregate(["mean", "median", "var", "std", "sem"])
summaryTable2
# Out:
#                    mean     median        var       std       sem
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using Pandas.
# grabbing the column for the drug regimen and doing value counts
# create plot doing pandas dataframe 
totalTimepoints = cleanedDF["Drug Regimen"].value_counts()
totalTimepoints.plot(kind="bar", xlabel = "Drug Regimen", ylabel = "Number of Timepoints", title = "Total # of Timepoints for All Mice by Drug Regimen")
plt.show()

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using pyplot.
uniqueDrugs = cleanedDF["Drug Regimen"].unique()
plt.bar(uniqueDrugs, totalTimepoints)
plt.xticks(rotation=90)
plt.title("Total # of Timepoints for All Mice by Drug Regimen")
plt.xlabel("Drug Regimen")
plt.ylabel("Number of Timepoints")
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas
sexDistribution = cleanedDF["Sex"].value_counts()
sexDistribution.plot(kind="pie", autopct="%1.1f%%")
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
sexDistribution
labels = ["Male", "Female"]
plt.pie(sexDistribution, labels=["Male", "Female"], autopct="%1.1f%%", shadow=True)
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin
# Start by getting the last (greatest) timepoint for each mouse
IDGrouped = cleanedDF.groupby(["Mouse ID"])
IDGroupedDF = pd.DataFrame(IDGrouped["Timepoint"].max())

# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
mergedData = pd.merge(IDGroupedDF, cleanedDF, how="left", on=["Mouse ID", "Timepoint"])

# %%
# Put treatments into a list for for loop (and later for plot labels)
treatmentList = ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]

# Create empty list to fill tumor volume data (for plotting)
tumorVolumeList = [] 
# Calculate the IQR and quantitatively determine if there are any potential outliers. 
for drug in treatmentList:
        
    # Locate the rows which contain mice on each drug and get the tumor volumes
    tumorVolume = mergedData.loc[mergedData["Drug Regimen"] == drug, "Tumor Volume (mm3)"]    
    tumorVolumeList.append(tumorVolume)
    # Determine outliers using upper and lower bounds
    quartiles = tumorVolume.quantile([0.25,.50,.75])
    lowerq = quartiles[0.25]
    upperq = quartiles[0.75]
    iqr = upperq-lowerq
    lowerBound = lowerq - (1.5*iqr)
    upperBound = upperq + (1.5*iqr)
    outliers = tumorVolume.loc[(tumorVolume<lowerBound) | (tumorVolume>upperBound)]

    # print the outliers
    print(f"{drug}'s potential outliers: {outliers}")
# Out:
# Capomulin's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Ramicane's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Infubinol's potential outliers: 31    36.321346
# Name: Tumor Volume (mm3), dtype: float64
# Ceftamin's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
fig1, ax1 = plt.subplots()
ax1.set_title('Final Tumor Volume of Each Mouse Across Four Drug Regimens')
ax1.set_ylabel('Final Tumor Volume (mm3)')
flierprops = {'marker': 'o', 'markersize': 10, 'markerfacecolor': 'red'} # customize the outlier of the boxplot
ax1.boxplot(tumorVolumeList, labels = treatmentList, flierprops=flierprops)
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin
mouseDF = cleanedDF[cleanedDF["Mouse ID"] == "b128"]
xAxis = mouseDF["Timepoint"]
yAxis = mouseDF["Tumor Volume (mm3)"]
plt.plot(xAxis, yAxis, color="red")
plt.xlabel("Timepoint (days)")
plt.ylabel("Tumor Volume (mm3)")
plt.title("Capomulin treatment of mouse b128")
plt.show()

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen
CapomulinDF = cleanedDF[cleanedDF["Drug Regimen"] == "Capomulin"]
groupedCapomulinDF = CapomulinDF.groupby("Mouse ID")
yAxis2 = (groupedCapomulinDF["Tumor Volume (mm3)"].mean())
xAxis2 = (groupedCapomulinDF["Weight (g)"].mean())
plt.scatter(xAxis2, yAxis2)
plt.xlabel("Weight (g)")
plt.ylabel("Average Tumor Volume (mm3)")
plt.title("Average Tumor Volume by Mouse Weight")
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(xAxis2, yAxis2)
regressValues = (xAxis2*slope) + intercept
lineEQ = f"y = {round(slope,2)}x + {round(intercept,2)}"
plt.scatter(xAxis2, yAxis2)
plt.plot(xAxis2, regressValues, "r-")
plt.annotate(lineEQ,(22,36), fontsize=10, color="red")
plt.xlabel("Weight (g)")
plt.ylabel("Average Tumor Volume (mm3)")
plt.title("Average Tumor Volume by Mouse Weight")
print(f"The correlation between mouse weight and the average tumor volume is {round(rvalue,2)}")
plt.show()
# Out:
# The correlation between mouse weight and the average tumor volume is 0.84
